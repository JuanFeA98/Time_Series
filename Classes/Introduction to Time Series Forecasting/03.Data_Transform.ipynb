# %% [markdown]
# ## **Librerías**

# %%
import pandas as pd
import numpy as np

# %%
pd.options.display.max_columns = False

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from scipy.stats import boxcox

# %% [markdown]
# ## **Datos**

# %%
airpasengers = pd.read_csv(
    '../../Data/AirPassengers.csv',
    header=0,
    index_col=0,
    parse_dates=True
)

airpasengers.head()
# Out:
#             #Passengers
# Month
# 1949-01-01          112
# 1949-02-01          118
# 1949-03-01          132
# 1949-04-01          129
# 1949-05-01          121

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 6))

fig.patch.set_facecolor('#21252b')

ax[0].plot(airpasengers)
ax[0].set_title('Número de pasajeros a lo largo del tiempo', color='white', weight=700)
ax[0].set_facecolor('#282c34')
ax[0].tick_params(colors='white')
ax[0].set_xlabel('Año', color='white')
ax[0].set_ylabel('Cantidad de vuelos', color='white')

ax[1].hist(airpasengers)
ax[1].set_title('Cantidad de vuelos por número de pasajeros', color='white', weight=700)
ax[1].set_facecolor('#282c34')
ax[1].tick_params(colors='white')
ax[1].set_xlabel('Número de pasajeros', color='white')
ax[1].set_ylabel('Cantidad de vuelos', color='white')

plt.subplots_adjust(hspace=0.7)

plt.show()

# %% [markdown]
# ## **Transformaciones**

# %% [markdown]
# ### **Raíz Cuadrada**

# %%
np.var(airpasengers['#Passengers'].apply(lambda x: x))
# Out:
# 14291.973331404319

# %%
np.var(airpasengers['#Passengers'].apply(lambda x: np.sqrt(x)))
# Out:
# 12.576771615619343

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 6))

fig.patch.set_facecolor('#21252b')

ax[0].plot(airpasengers['#Passengers'].apply(lambda x: x))
ax[0].set_facecolor('#282c34')
ax[0].tick_params(colors='white')
ax[0].set_ylabel('', color='white')

ax[1].plot(airpasengers['#Passengers'].apply(lambda x: np.sqrt(x)))
ax[1].set_facecolor('#282c34')
ax[1].tick_params(colors='white')
ax[1].set_ylabel('', color='white')

plt.subplots_adjust(hspace=0.7)

plt.show()

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 6))

fig.patch.set_facecolor('#21252b')

ax[0].hist(airpasengers['#Passengers'].apply(lambda x: x))
ax[0].set_facecolor('#282c34')
ax[0].tick_params(colors='white')
ax[0].set_ylabel('', color='white')

ax[1].hist(airpasengers['#Passengers'].apply(lambda x: np.sqrt(x)))
ax[1].set_facecolor('#282c34')
ax[1].tick_params(colors='white')
ax[1].set_ylabel('', color='white')

plt.subplots_adjust(hspace=0.7)

plt.show()

# %% [markdown]
# ### **Logaritmo Natural**

# %%
np.var(airpasengers['#Passengers'].apply(lambda x: x))
# Out:
# 14291.973331404319

# %%
np.var(airpasengers['#Passengers'].apply(lambda x: np.log(x)))
# Out:
# 0.19353041493967493

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 6))

fig.patch.set_facecolor('#21252b')

ax[0].plot(airpasengers['#Passengers'].apply(lambda x: x))
ax[0].set_facecolor('#282c34')
ax[0].tick_params(colors='white')
ax[0].set_ylabel('', color='white')

ax[1].plot(airpasengers['#Passengers'].apply(lambda x: np.log(x)))
ax[1].set_facecolor('#282c34')
ax[1].tick_params(colors='white')
ax[1].set_ylabel('', color='white')

plt.subplots_adjust(hspace=0.7)

plt.show()

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 6))

fig.patch.set_facecolor('#21252b')

ax[0].hist(airpasengers['#Passengers'].apply(lambda x: x))
ax[0].set_facecolor('#282c34')
ax[0].tick_params(colors='white')
ax[0].set_ylabel('', color='white')

ax[1].hist(airpasengers['#Passengers'].apply(lambda x: np.log(x)))
ax[1].set_facecolor('#282c34')
ax[1].tick_params(colors='white')
ax[1].set_ylabel('', color='white')

plt.subplots_adjust(hspace=0.7)

plt.show()

# %% [markdown]
# ### **Box-Cox**

# %%
np.var(airpasengers['#Passengers'].apply(lambda x: x))
# Out:
# 14291.973331404319

# %%
datos_transformados, lambda_optimo = boxcox(airpasengers['#Passengers'])

# %%
boxcox(airpasengers['#Passengers'], lmbda=0.14)
# Out:
# array([ 6.68524209,  6.78664022,  7.00700845,  6.96153986,  6.83568616,
#         7.05159686,  7.23547807,  7.23547807,  7.06627037,  6.80310683,
#         6.54251564,  6.78664022,  6.73650993,  6.91515262,  7.13827508,
#         7.05159686,  6.89947904,  7.24903985,  7.51717131,  7.51717131,
#         7.36769561,  7.02196723,  6.71954979,  7.1240518 ,  7.1943145 ,
#         7.26252357,  7.6118558 ,  7.43112486,  7.54119598,  7.6118558 ,
#         7.84402855,  7.84402855,  7.68049615,  7.41857418,  7.20811641,
#         7.46838361,  7.52921385,  7.6349541 ,  7.77993149,  7.64642059,
#         7.66919107,  8.03658718,  8.15088844,  8.26017124,  7.9472542 ,
#         7.75818475,  7.54119598,  7.79073227,  7.81219096,  7.81219096,
#         8.20612726,  8.19700529,  8.14156176,  8.26906629,  8.44895215,
#         8.51425315,  8.21521604,  7.96738792,  7.6349541 ,  7.86502506,
#         7.8961854 ,  7.72519458,  8.19700529,  8.12280282,  8.18784989,
# ...

# %%
np.var(datos_transformados)
# Out:
# 0.9944972207370016

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 6))

fig.patch.set_facecolor('#21252b')

ax[0].plot(airpasengers['#Passengers'].apply(lambda x: x))
ax[0].set_facecolor('#282c34')
ax[0].tick_params(colors='white')
ax[0].set_ylabel('', color='white')

ax[1].plot(datos_transformados)
ax[1].set_facecolor('#282c34')
ax[1].tick_params(colors='white')
ax[1].set_ylabel('', color='white')

plt.subplots_adjust(hspace=0.7)

plt.show()

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 6))

fig.patch.set_facecolor('#21252b')

ax[0].hist(airpasengers['#Passengers'].apply(lambda x: x))
ax[0].set_facecolor('#282c34')
ax[0].tick_params(colors='white')
ax[0].set_ylabel('', color='white')

ax[1].hist(datos_transformados)
ax[1].set_facecolor('#282c34')
ax[1].tick_params(colors='white')
ax[1].set_ylabel('', color='white')

plt.subplots_adjust(hspace=0.7)

plt.show()
